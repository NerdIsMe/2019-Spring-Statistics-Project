# %%
import numpy as np
import pandas as pd 
import datetime
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['figure.dpi'] = 130

# %% [markdown]
# ## DSAP 107

# %%
grades = pd.read_csv('../../data/DSAP107 grades.csv')
v_info = pd.read_excel('../../data/DSAP107 videos_sep.xlsx', sheet_name = 'video info')
records = pd.read_excel('../../data/DSAP107 videos_sep.xlsx', sheet_name = 'watching records')

# %%
o1 = pd.read_excel('./每週播放速度 data/video_dsap_107_(in order).xlsx')

# %%
o1
# Out:
#     Unnamed: 0                                   Unnamed: 1 Unnamed: 2
# 0         4585                         C++ string functions        NaN
# 1         4586                         C++ string operators        NaN
# 2         4587                           Chinese characters        NaN
# 3         4588                                 Introduction        NaN
# 4         4600                        Writing to a file (1)        NaN
# 5         4601                        Writing to a file (2)        NaN
# 6         4598         Reading from an unformatted file (1)        NaN
# 7         4599         Reading from an unformatted file (2)        NaN
# 8         4596                                  End of file        NaN
# 9         4597           Reading from a well-formatted file        NaN
# 10        4602                Self-defined header files (1)        NaN
# 11        4603                Self-defined header files (2)         ….
# 12        4605                  Introduction to Inheritance        NaN
# 13        4606                       More about inheritance        NaN
# 14        4604                          Function overriding        NaN
# 15        4607                            Relevant concepts        NaN
# 16        4581              Issues about Warrior and Wizard        NaN
# 17        4582                          The class Character        NaN
# 18        4613                                   An example        NaN
# 19        4614                       Early and late binding        NaN
# 20        4615                 Introduction to polymorphism        NaN
# 21        4616                          Remaining questions        NaN
# 22        4617                            Virtual functions         ….
# 23        4619                                Templates (2)        NaN
# 24        4620                                Templates (3)        NaN
# 25        4621              The standard library vector (1)        NaN
# 26        4622              The standard library vector (2)        NaN
# 27        4618                                Templates (1)        NaN
# 28        4593                       Exception handling (1)        NaN
# 29        4594                       Exception handling (2)        NaN
# 30        4595                       Exception handling (3)         ….
# 31        5441                            OOA, OOD, and OOP        NaN
# 32        5442                          Abstract data types        NaN
# 33        5443                                The ADT "bag"        NaN
# 34        5444                     Static-array bag - add()        NaN
# 35        5445                  Static-array bag - remove()        NaN
# 36        5446                   Static-array bag - remarks        NaN
# 37        5447                            Dynamic-array bag        NaN
# 38        5448                        Link-based bad - Node        NaN
# 39        5449        Link-based bag - add() and toVector()        NaN
# 40        5450                    Link-based bag - remove()        NaN
# 41        5451  Link-based bag - constructor and destructor        NaN
# 42        5452                                Final remarks         ….
# 43        5587                                Binary Search        NaN
# 44        5588                        Factorial and Maximum        NaN
# 45        5589                                  Combination        NaN
# 46        5590                                  Hanoi Tower        NaN
# 47        5591                      Recursion vs. Iteration        NaN
# 48        5592                                     Knapsack        NaN
# 49        5593                       Recursion for Knapsack        NaN
# 50        5594             Dynamic Programming for Knapsack        NaN
# 51        5595            Maximum Flow and Augmenting Paths        NaN
# 52        5596                            Residual Networks        NaN
# 53        5597               Efficiency of Augmenting Paths         ….
