# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('D:\python statistic\data\OR107 grades.csv')

print('Head of dataset:')
display(df1.head())

print("Tail of dataset:")
display(df1.tail())
# Out:
# Head of dataset:
#             student-id                         Section  \
# 0      Points Possible                             NaN
# 1                   88  107-2 作業研究 Operations Research
# 2                   89  107-2 作業研究 Operations Research
# 3                   90  107-2 作業研究 Operations Research
# 4                   91  107-2 作業研究 Operations Research
#
#    Case Assignment 1 (1579)  Case Assignment 2 (1843)  \
# 0                     100.0                     100.0
# 1                      72.0                       NaN
# 2                      72.0                      82.0
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    Case Assignment 3 (2014)  Pre-lecture problems for Lecture 2 (1631)  \
# 0                     100.0                                       10.0
# 1                       NaN                                        NaN
# ...

# %%
df1 = df1.fillna(0)
df1
# Out:
#              student-id                         Section  \
# 0       Points Possible                               0
# 1                    88  107-2 作業研究 Operations Research
# 2                    89  107-2 作業研究 Operations Research
# 3                    90  107-2 作業研究 Operations Research
# 4                    91  107-2 作業研究 Operations Research
# ..                  ...                             ...
# 79                  166  107-2 作業研究 Operations Research
# 80                  167  107-2 作業研究 Operations Research
# 81                  168  107-2 作業研究 Operations Research
# 82                  169  107-2 作業研究 Operations Research
# 83                  170  107-2 作業研究 Operations Research
#
#     Case Assignment 1 (1579)  Case Assignment 2 (1843)  \
# 0                      100.0                     100.0
# 1                       72.0                       0.0
# 2                       72.0                      82.0
# 3                        0.0                       0.0
# ...

# %%
df2 = [df1['student-id'], df1['Final Exam (2231)'] ]
df2 = pd.DataFrame(df2)
df2 = df2.T
df2
# Out:
#              student-id Final Exam (2231)
# 0       Points Possible               100
# 1                    88                 0
# 2                    89                41
# 3                    90                 0
# 4                    91                 0
# ..                  ...               ...
# 79                  166                70
# 80                  167                 0
# 81                  168                75
# 82                  169                82
# 83                  170                 0
#
# [84 rows x 2 columns]

# %%
df2.to_excel(r'D:\python statistic\data\result_OR 107.xlsx', index = False)
