# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('D:\python statistic\data\OR108 grades.csv')

print('Head of dataset:')
display(df1.head())

print("Tail of dataset:")
display(df1.tail())
# Out:
# Head of dataset:
#             student_id                   Section  Homework 1 (5323)  \
# 0      Points Possible                       NaN              100.0
# 1                    8  作業研究 Operations Research                NaN
# 2                    9  作業研究 Operations Research               58.0
# 3                   10  作業研究 Operations Research                NaN
# 4                   11  作業研究 Operations Research                NaN
#
#    Homework 2 (5324)  Lecture problems for Lecture 2 (6960)  \
# 0              100.0                                   10.0
# 1                NaN                                    0.0
# 2                NaN                                   10.0
# 3                NaN                                    0.0
# 4                NaN                                   10.0
#
#    Lecture problems for Lecture 3 (7183)  \
# 0                                   10.0
# 1                                    0.0
# 2                                    6.0
# ...

# %%
df1 = df1.fillna(0)
df1
# Out:
#               student_id                   Section  Homework 1 (5323)  \
# 0        Points Possible                         0              100.0
# 1                      8  作業研究 Operations Research                0.0
# 2                      9  作業研究 Operations Research               58.0
# 3                     10  作業研究 Operations Research                0.0
# 4                     11  作業研究 Operations Research                0.0
# ..                   ...                       ...                ...
# 102                  109  作業研究 Operations Research               71.0
# 103                  110  作業研究 Operations Research               88.0
# 104                  111  作業研究 Operations Research               69.0
# 105                  112  作業研究 Operations Research               83.0
# 106                  113  作業研究 Operations Research               75.0
#
#      Homework 2 (5324)  Lecture problems for Lecture 2 (6960)  \
# 0                100.0                                   10.0
# ...

# %%
df2 = [df1['student_id']]
df2 = pd.DataFrame(df2)
df2 = df2.T
df2 = df2.drop(df2.index[[0]])
df2['avg_week_result'] = 0 
df2
# Out:
#     student_id  avg_week_result
# 1            8                0
# 2            9                0
# 3           10                0
# 4           11                0
# 5           12                0
# ..         ...              ...
# 102        109                0
# 103        110                0
# 104        111                0
# 105        112                0
# 106        113                0
#
# [106 rows x 2 columns]

# %%
for i in range(1,107):
    
             df2['avg_week_result'][i]= ( df1['Lecture problems for Lecture 2 (6960)'][i]
                                         + df1['Lecture problems for Lecture 3 (7183)'][i]+ df1['Lecture problems for Lecture 4 (8211)'][i] 
                                         + df1['Lecture problems for Lecture 5 (9672)'][i]+ df1['Lecture problems for Lecture 6 (10335)'][i] 
                                         +df1['Lecture problems for Lecture 7 (10924)'][i] +df1['Lecture problems for Lecture 8 (11901)'][i] 
                                         + df1['Lecture problems for Lecture 9 (12376)'][i] ) /8
# Out:
# C:\Users\dlkk9\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
pd.set_option('display.max_rows', df2.shape[0]+1)
df2
# Out:
#     student_id  avg_week_result
# 1            8                0
# 2            9                8
# 3           10                0
# 4           11                9
# 5           12                0
# 6           13                0
# 7           14                0
# 8           15                0
# 9           16                0
# 10          17                8
# 11          18                6
# 12          19                0
# 13          20                6
# 14          21                9
# 15          22                8
# 16          23                8
# 17          24                0
# 18          25                9
# 19          26                9
# 20          27                0
# 21          28                0
# 22          29                9
# 23          30                4
# 24          31                7
# 25          32                8
# 26          33                9
# 27          34                8
# 28          35                0
# ...

# %%
df2.to_excel(r'D:\python statistic\data\avg_week_result_OR 108.xlsx', index = False)
