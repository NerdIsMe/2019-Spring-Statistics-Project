# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('D:\python statistic\data\DSAP107 grades.csv')

print('Head of dataset:')
display(df1.head())

print("Tail of dataset:")
display(df1.tail())
# Out:
# Head of dataset:
#             student_id            Section  Homework 0 (1554)  \
# 0      Points Possible                NaN                100
# 1                   64  107-2 資料結構與進階程式設計                  0
# 2                   65  107-2 資料結構與進階程式設計                 14
# 3                   66  107-2 資料結構與進階程式設計                 88
# 4                   67  107-2 資料結構與進階程式設計                 99
#
#    Homework 1 (1475)  Homework 2 (1750)  Homework 3 (1808)  Homework 4 (1859)  \
# 0                100                100                100                100
# 1                  0                  0                  0                  0
# 2                  0                  0                  0                  0
# 3                 39                 96                104                 69
# 4                 95                 46                 92                 32
#
#    Homework 5 (1954)  Homework 6 (2053)  Homework 7 (2129)  Homework8 (2232)  \
# ...

# %%
df1 = df1.fillna(0)
df1
# Out:
#               student_id            Section  Homework 0 (1554)  \
# 0        Points Possible                  0                100
# 1                     64  107-2 資料結構與進階程式設計                  0
# 2                     65  107-2 資料結構與進階程式設計                 14
# 3                     66  107-2 資料結構與進階程式設計                 88
# 4                     67  107-2 資料結構與進階程式設計                 99
# ..                   ...                ...                ...
# 101                  164  107-2 資料結構與進階程式設計                100
# 102                  165  107-2 資料結構與進階程式設計                 91
# 103                  166  107-2 資料結構與進階程式設計                100
# 104                  167  107-2 資料結構與進階程式設計                 91
# 105                  168  107-2 資料結構與進階程式設計                 62
#
#      Homework 1 (1475)  Homework 2 (1750)  Homework 3 (1808)  \
# 0                  100                100                100
# 1                    0                  0                  0
# ...

# %%
df2 = [df1['student_id']]
df2 = pd.DataFrame(df2)
df2 = df2.T
df2 = df2.drop(df2.index[[0]])
df2['avg_week_result'] = 0 
df2
# Out:
#     student_id  avg_week_result
# 1           64                0
# 2           65                0
# 3           66                0
# 4           67                0
# 5           68                0
# ..         ...              ...
# 101        164                0
# 102        165                0
# 103        166                0
# 104        167                0
# 105        168                0
#
# [105 rows x 2 columns]

# %%
for i in range(1,106):
    
            a = ( df1['Homework 0 (1554)'][i] + df1['Homework 1 (1475)'][i]+ df1['Homework 2 (1750)'][i] + df1['Homework 3 (1808)'][i] + df1['Homework 4 (1859)'][i] +df1['Homework 5 (1954)'][i] +df1['Homework 6 (2053)'][i] + df1['Homework 7 (2129)'][i] + df1['Homework8 (2232)'][i] ) /9
            df2['avg_week_result'][i] = a
# Out:
# C:\Users\dlkk9\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df2
# Out:
#     student_id  avg_week_result
# 1           64                0
# 2           65                1
# 3           66               77
# 4           67               72
# 5           68               66
# ..         ...              ...
# 101        164               86
# 102        165               93
# 103        166               96
# 104        167              100
# 105        168               79
#
# [105 rows x 2 columns]

# %%
df2.to_excel(r'D:\python statistic\data\avg_week_result_DSAP 107.xlsx', index = False)
