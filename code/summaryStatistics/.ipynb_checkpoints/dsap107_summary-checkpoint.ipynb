# %% [markdown]
# ## DSAP107

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# 設定圖形大小; DPI越大圖越大
plt.rcParams["figure.dpi"] = 150
import seaborn as sns

import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as smm
import statsmodels.stats.libqsturng as ssl
import statsmodels.stats.outliers_influence as sso
import math

# %% [markdown]
# ### Summary Statistics

# %%
dsap107 = pd.read_excel('/Users/chihsin1/Documents/stats2_finalProject_data/DSAP107.xlsx')
print('Head of dataset:')
display(dsap107.head())

print("Tail of dataset:")
display(dsap107.tail())
# Out:
# Head of dataset:
#    student_id  midterm  final  total_watch_time  avg_playback_rate  avg_freq  \
# 0          64        0    0.0      13331.983333           1.492651  0.563979
# 1          65        0    0.0       3572.000000           1.000000  0.101233
# 2          66       82   76.0      36625.000000           1.000000  1.037976
# 3          67       79   79.0      18789.383333           1.847426  0.983761
# 4          68       52   57.0      13719.766667           1.742595  0.677568
#
#    backward_sec  backward_times  forward_sec  forward_times  pause_freq
# 0           555              27         1517             10         112
# 1            97               9          442              9          15
# 2          6718             183         7937            258         546
# 3          6466             120         6789            163         473
# 4          3991              93         6939            196         333
# Tail of dataset:
#      student_id  midterm  final  total_watch_time  avg_playback_rate  \
# 100         164        0   88.0      28647.200000           1.376958
# 101         165        0   55.0       6125.250000           1.626709
# 102         166       90   76.0      18766.033333           1.279866
# 103         167       91   54.0      17117.583333           1.565057
# 104         168       74   58.0      28334.883333           1.843805
#
#      avg_freq  backward_sec  backward_times  forward_sec  forward_times  \
# 100  1.117925          6430             666         5978            347
# 101  0.282386          2417              53         4311             61
# 102  0.680686          4038             365         2600            103
# 103  0.759246          3392              61         2692             39
# 104  1.480629         12719             465         6213            339
#
#      pause_freq
# 100        1160
# 101         139
# 102         327
# 103         221
# 104         952

# %%
#summary statistics
dsap107.describe()
# Out:
#        student_id     midterm       final  total_watch_time  \
# count  105.000000  105.000000  105.000000        105.000000
# mean   116.000000   47.838095   47.890476      18651.977256
# std     30.454885   41.221989   34.290121      12435.747678
# min     64.000000    0.000000    0.000000          0.000000
# 25%     90.000000    0.000000    0.000000      12851.733333
# 50%    116.000000   73.000000   60.000000      18766.033333
# 75%    142.000000   85.000000   76.000000      26227.966667
# max    168.000000   98.000000   91.500000      69769.233333
#
#        avg_playback_rate    avg_freq  backward_sec  backward_times  \
# count         105.000000  105.000000    105.000000      105.000000
# mean            1.436895    0.805038   6169.209524      172.847619
# std             0.459068    0.518082   8287.920958      206.699837
# min             0.000000    0.000000      0.000000        0.000000
# 25%             1.248772    0.559133    722.000000       32.000000
# 50%             1.480752    0.800567   3889.000000       75.000000
# 75%             1.745431    1.082840   8919.000000      272.000000
# max             2.380491    2.785461  47475.000000      905.000000
#
#         forward_sec  forward_times   pause_freq
# count    105.000000     105.000000   105.000000
# mean    5696.952381     239.619048   452.742857
# std     7815.918138     410.113314   488.764377
# min        0.000000       0.000000     0.000000
# 25%      895.000000      13.000000   123.000000
# 50%     2615.000000      74.000000   293.000000
# 75%     6939.000000     311.000000   667.000000
# max    46388.000000    2368.000000  2538.000000

# %%
corr = dsap107.corr()
_ = sns.heatmap(corr, annot=True)

# %% [markdown]
# ### Scatter Diagram

# %% [markdown]
# #### Midterm

# %%
y = dsap107['midterm'].values
xnames = ['total_watch_time', 'avg_playback_rate', 'avg_freq', "backward_sec", "backward_times", "forward_sec", "forward_times", "pause_freq"]
for aname in xnames:
    x = dsap107[aname].values

    _ = plt.plot(x, y, 'o', color = 'b')
    plt.xlabel(aname)
    plt.ylabel('Midterm')
    plt.show()

# %% [markdown]
# #### Final

# %%
y = dsap107['final'].values
xnames = ['total_watch_time', 'avg_playback_rate', 'avg_freq', "backward_sec", "backward_times", "forward_sec", "forward_times", "pause_freq"]
for aname in xnames:
    x = dsap107[aname].values

    _ = plt.plot(x, y, 'o', color = 'b')
    plt.xlabel(aname)
    plt.ylabel('Final')
    plt.show()
